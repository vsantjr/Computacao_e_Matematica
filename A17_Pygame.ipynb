# %% [markdown]
# <img src="https://drive.google.com/uc?id=1Xy-x8LjUOmFLEWCCatqIzSbGKw2AeNbA" alt="Drawing" width="850"/>

# %% [markdown]
# ## **Jogos e Matemática**
#
# ---
#
# O que tem a ver Jogos (*Games*) com Matemática? Simplesmente tudo. Se é preciso calcular a trajetória de um Avião voando pelo céu ou fazer com que um Guerreiro salte para não ser ferido por um adversário, tudo isso envolve Matemática ''codificada'' em linguagens de programação.
#
#
# \\
#
# <img src="https://drive.google.com/uc?id=1PkuqIhfHKm2Rg8bdLLpxhzAcSnb2on4r" alt="Drawing" width="500"/>
#
# *Final Fantasy VII Remake*. Image by <a href="https://www.showmetech.com.br/review-final-fantasy-7-remake/">SHOWMETECH.</a>
#
# \\
#
#
# \\
#
# <img src="https://drive.google.com/uc?id=1s7W50UYPwX0KJTlwetkdl0wCei_u_RmM" alt="Drawing" width="500"/>
#
# *Among Us*. Image by <a href="https://www.techtudo.com.br/dicas-e-tutoriais/2019/12/como-jogar-among-us-com-amigos.ghtml">techtudo.</a>
#
# \\

# %% [markdown]
# ## **Fazendo Jogos em Python: Visão Geral**
# ----
#
# *Pygame* é uma biblioteca de jogos multiplataforma (independente de sistema
# operacional) feita para ser utilizada em conjunto com a linguagem de
# programação *python*.
#
# \\
#
# <img src="https://drive.google.com/uc?id=13JR6KkJCdpolN83XTbDzh1OowJqZaELm" alt="Drawing" width="700"/>
#
# Image by <a href="https://www.pygame.org/tags/gpl">Pygame.</a>
#
# \\
#
# **Convenção de Coordenadas**
#
# \\
#
# <img src="https://drive.google.com/uc?id=1UoCEJ2kLlca3RtAcyR6y3LsBC9ORQq_T" alt="Drawing" width="500"/>

# %% [markdown]
# ## **Acesso aos Programas**
#
# Todos os programas (`.ipynb`, `.py`) podem ser acessados (feito download) via esse link:
# <a href="https://github.com/vsantjr/Computacao_e_Matematica">Computação e Matemática</a>.
